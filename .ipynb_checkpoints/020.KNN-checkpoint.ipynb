# %% [markdown]
# # 020.KNN (K-Nearest Neighbors, 최근접 이웃)

# %% [markdown]
# ### iris dataset
#
# iris.feature_names :
#
# Sepal Length : 꽃받침 길이
# Sepal Width  : 꽃받침 너비
# Petal Length  : 꽃잎 길이
# Petal Width   :  꽃잎 너비
#
# Species (꽃의 종류) :  setosa / versicolor / virginica 의 3종류로 구분된다.
#
# **꽃받침 길이, 너비 두가지 feature 를 가지고 KNN 알고리즘을 이용하여 꽃의 종류 분류**

# %% [markdown]
# **neighbors.KNeighborsClassifier(n_neighbors, weights=weights)**
#
# - weights :
#
#     - uniform : uniform weights. 모든 neighbor 의 가중치를 동일하게 취급
#     - distance : neighbor 의 거리에 반비례하여 가중치 조정

# %%
# 필요한 라이브러리 import
import numpy as np  # 수치 연산
from sklearn.datasets import load_iris  # 아이리스 데이터셋
from sklearn.neighbors import KNeighborsClassifier  # KNN 분류기

# %%
# 아이리스 데이터셋 로드
iris = load_iris()

# 데이터셋 정보 확인
print(iris.data.shape)  # 데이터 크기 (샘플 수, 특성 수)
print(iris.feature_names)  # 특성 이름
print(iris.target_names)  # 타겟(클래스) 이름
# Out:
# (150, 4)
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %%
# 꽃받침 길이, 너비 두가지 feature 선택
# [:, :2]는 모든 행에서 처음 2개 열(꽃받침 길이, 너비)만 선택
X = iris.data[:, :2]
y = iris.target  # 타겟(클래스) 레이블

# 처음 5개 샘플의 특성과 레이블 확인
print(X[:5])  # 처음 5개 샘플의 특성 값
print()
print(y[:5])  # 처음 5개 샘플의 레이블
# Out:
# [[5.1 3.5]
#  [4.9 3. ]
#  [4.7 3.2]
#  [4.6 3.1]
#  [5.  3.6]]
#
# [0 0 0 0 0]

# %%
# 학습/테스트 데이터셋 분할
from sklearn.model_selection import train_test_split
# 기본적으로 75%는 학습용, 25%는 테스트용으로 분할
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ### KNN object 생성 및 train

# %%
# KNN 분류기 객체 생성
# n_neighbors=15: 가장 가까운 15개의 이웃을 고려
# weights='uniform': 모든 이웃의 가중치를 동일하게 취급
clf = KNeighborsClassifier(n_neighbors=15, weights='uniform')
# 학습 데이터로 모델 훈련
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
# 테스트 데이터에 대한 예측 수행
y_predict = clf.predict(X_test)
# 예측 결과 확인
y_predict
# Out:
# array([0, 0, 2, 2, 1, 0, 0, 1, 0, 2, 1, 0, 1, 1, 1, 0, 1, 1, 0, 2, 2, 1,
#        0, 1, 0, 0, 1, 1, 1, 2, 0, 1, 2, 2, 0, 1, 1, 0])

# %%
# pip install seaborn

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 혼돈 행렬 계산
cm = confusion_matrix(y_test, y_predict)

plt.figure(figsize=(6, 4))

# Heatmap 시각화
sns.heatmap(cm, annot=True, fmt='d', cmap='YlOrRd')  # 숫자 표시, 파란색 계열
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 예측의 정확도 평가

# %%
# 정확도 평가를 위한 함수 import
from sklearn.metrics import accuracy_score

# %%
# 정확도 계산: 올바르게 예측한 샘플의 비율
accuracy_score(y_test, y_predict)
# Out:
# 0.8157894736842105

# %% [markdown]
# ### 예측 시각화

# %%
# 시각화를 위한 라이브러리 import
import matplotlib.pyplot as plt

# 트레이닝 데이터 세트에서 각 클래스에 따른 데이터 포인트를 산점도로 그림
for i in range(3):
    # i번째 클래스에 해당하는 데이터 포인트만을 선택하여 산점도를 그림
    # X_train[y_train == i, 0]: i번째 클래스의 첫 번째 특성(꽃받침 길이)
    # X_train[y_train == i, 1]: i번째 클래스의 두 번째 특성(꽃받침 너비)
    plt.scatter(X_train[y_train == i, 0], X_train[y_train == i, 1], label=str(i))
    
# 테스트 데이터 세트에서 하나의 데이터 포인트를 붉은색 'x' 마커로 그림
plt.plot(X_test[20,0], X_test[20,1], c='r', marker='x', markersize=20)

# 범례를 표시
plt.legend()

# clf 분류기를 사용하여 선택된 테스트 데이터 포인트의 라벨을 예측하고 결과를 출력
print(clf.predict(X_test[20:21]))
# Out:
# [2]

# %%
# 테스트 데이터의 실제 레이블 확인
y_test
# Out:
# array([0, 0, 2, 2, 2, 0, 0, 1, 0, 2, 1, 0, 1, 1, 1, 0, 2, 2, 0, 2, 2, 2,
#        0, 2, 0, 0, 1, 2, 2, 2, 0, 1, 2, 2, 0, 1, 1, 0])

# %%
# 특정 테스트 샘플(인덱스 2)에 대한 예측 수행
clf.predict([X_test[2]])
# Out:
# array([2])

# %% [markdown]
# ### 혼돈 행렬

# %%
# 혼돈 행렬(Confusion Matrix) 계산
from sklearn.metrics import confusion_matrix

# 혼돈 행렬 생성: 실제 레이블과 예측 레이블을 비교
cm = confusion_matrix(y_test, y_predict)
# 혼돈 행렬 출력
cm
# Out:
# array([[14,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  7,  8]])

# %%
# 혼돈 행렬 시각화를 위한 라이브러리 import
import seaborn as sns

# 그래프 크기 설정
plt.figure(figsize=(5,4))

# 혼돈 행렬을 히트맵으로 시각화
# annot=True: 각 셀에 숫자 표시, fmt='d': 정수 형식으로 표시
ax = sns.heatmap(cm, annot=True, fmt='d', cmap='YlOrRd')
ax.set_ylabel('True')  # y축 레이블: 실제 레이블
ax.set_title('Confusion Matirx\nPredicted')  # 제목: 예측 레이블
None

# %% [markdown]
# # 실습
#
# n_neighbors 를 변경하여 Test. Visualization 을 통하여 위 결과와 비교.

# %%
# n_neighbors를 20으로 변경하여 새로운 KNN 분류기 생성
clf = KNeighborsClassifier(n_neighbors=20, weights='uniform')

# 모델 훈련 (your code here)
clf.fit(X_train, y_train)

# 테스트 데이터에 대한 예측 수행
y_predict = clf.predict(X_test)
# 정확도 출력
print("accuracy = {}".format(accuracy_score(y_test, y_predict)))
# Out:
# accuracy = 0.8421052631578947
